# %%
from espncricinfo.summary import Summary
from espncricinfo.match import Match 
from espncricinfo.series import Series

import json
import requests
from bs4 import BeautifulSoup
from espncricinfo.exceptions import MatchNotFoundError, NoScorecardError

import pandas as pd
# Out:
# C:\Users\rbat\AppData\Local\Continuum\anaconda3\lib\site-packages\grequests.py:21: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.contrib.pyopenssl (C:\\Users\\rbat\\AppData\\Local\\Continuum\\anaconda3\\lib\\site-packages\\urllib3\\contrib\\pyopenssl.py)', 'urllib3.util (C:\\Users\\rbat\\AppData\\Local\\Continuum\\anaconda3\\lib\\site-packages\\urllib3\\util\\__init__.py)'].
#   curious_george.patch_all(thread=False, select=False)
# C:\Users\rbat\AppData\Local\Continuum\anaconda3\lib\site-packages\gevent\hub.py:154: UserWarning: libuv only supports millisecond timer resolution; all times less will be set to 1 ms
#   with loop.timer(seconds, ref=ref) as t:

# %%
testlist = ['1119496', '1022353']

# %%
Match(a).match_url
# Out:
# 'http://www.espncricinfo.com/matches/engine/match/1119496.html'
# C:\Users\rbat\AppData\Local\Continuum\anaconda3\lib\site-packages\gevent\hub.py:154: UserWarning: libuv only supports millisecond timer resolution; all times less will be set to 1 ms
#   with loop.timer(seconds, ref=ref) as t:

# %%
def flatten(js):
    return pd.DataFrame(js).set_index(['text','name']).squeeze()
# Out:
# C:\Users\rbat\AppData\Local\Continuum\anaconda3\lib\site-packages\gevent\hub.py:154: UserWarning: libuv only supports millisecond timer resolution; all times less will be set to 1 ms
#   with loop.timer(seconds, ref=ref) as t:

# %%
def getbattingdatafame(list1):
    df = pd.DataFrame()
    for x in list1:
        x1 = Match(x).html
        x2 = json.loads(x1.find_all('script')[12].get_text().replace("\n", " ").replace('window.__INITIAL_STATE__ =','').replace('&dagger;','wk').replace('&amp;','').replace('wkts;','wkts,').replace('wkt;','wkt,').strip().replace('};', "}};").split('};')[0])
        df1bat = pd.DataFrame(x2['gamePackage']['scorecard']['innings']['1']['batsmen'])
        d1title = x2['gamePackage']['scorecard']['innings']['1']['title']
        df1bat['Team'] = d1title.split(' ')[0]
        df2bat = pd.DataFrame(x2['gamePackage']['scorecard']['innings']['2']['batsmen'])
        d2title = x2['gamePackage']['scorecard']['innings']['2']['title']
        df2bat['Team'] = d2title.split(' ')[0]
        df1bat['Oppositionteam'] = d2title.split(' ')[0]
        df2bat['Oppositionteam'] = d1title.split(' ')[0]
        
        Finaldf_bat = pd.concat([df1bat.drop(['captain','commentary','runningScore','runningOver', 'stats','hasVideoId','href','isNotOut','roles','shortText','trackingName'], axis=1),
#           df1.runningScore.apply(pd.Series),
           df1bat.stats.apply(flatten)], axis=1).append(pd.concat([df2bat.drop(['captain','commentary','runningScore','runningOver', 'stats','hasVideoId','href','isNotOut','roles','shortText','trackingName'], axis=1),
#                                                               df2.runningScore.apply(pd.Series),
                                                               df2bat.stats.apply(flatten)], axis=1))
        Finaldf_bat['city'] = Match(x).town_name
        Finaldf_bat['date'] = Match(x).date
        df=pd.concat([df,Finaldf_bat])
    return(df)
# Out:
# C:\Users\rbat\AppData\Local\Continuum\anaconda3\lib\site-packages\gevent\hub.py:154: UserWarning: libuv only supports millisecond timer resolution; all times less will be set to 1 ms
#   with loop.timer(seconds, ref=ref) as t:

# %%
getbattingdatafame(testlist)
# Out:
#                name       Team Oppositionteam (R, runs) (B, ballsFaced)  \
# 0         AM Rahane      India      Australia         5              15
# 1         RG Sharma      India      Australia        28              44
# 2           V Kohli      India      Australia         0               4
# 3         MK Pandey      India      Australia         0               2
# 4         KM Jadhav      India      Australia        40              54
# 5          MS Dhoni      India      Australia        79              88
# 6         HH Pandya      India      Australia        83              66
# 7           B Kumar      India      Australia        32              30
# 8     Kuldeep Yadav      India      Australia         0               0
# 0         DA Warner  Australia          India        25              28
# 1    HWR Cartwright  Australia          India         1               8
# 2         SPD Smith  Australia          India         1               5
# 3           TM Head  Australia          India         5               6
# 4        GJ Maxwell  Australia          India        39              18
        x2 = json.loads(x1.find_all('script')[12].get_text().replace("\n", " ").replace('window.__INITIAL_STATE__ =','').replace('&dagger;','wk').replace('&amp;','').replace('wkts;','wkts,').replace('wkt;','wkt,').strip().replace('};', "}};").split('};')[0])
        df1bowl = pd.DataFrame(x2['gamePackage']['scorecard']['innings']['1']['bowlers'])
        d1title = x2['gamePackage']['scorecard']['innings']['1']['title']
        df2bowl = pd.DataFrame(x2['gamePackage']['scorecard']['innings']['2']['bowlers'])
        d2title = x2['gamePackage']['scorecard']['innings']['2']['title']
        df1bowl['Team'] = d2title.split(' ')[0]
        df2bowl['Team'] = d1title.split(' ')[0]
        df1bowl['Oppositionteam'] = d1title.split(' ')[0]
        df2bowl['Oppositionteam'] = d2title.split(' ')[0]
        
        Finaldf_bowl = pd.concat([df1bowl.drop(['captain','stats','hasVideoId','href','roles','trackingName'], axis=1),
                       df1bowl.stats.apply(flatten)], axis=1).append(pd.concat([df2bowl.drop(['captain','stats','hasVideoId','href','roles','trackingName'], axis=1),
                                                               df2bowl.stats.apply(flatten)], axis=1))
        Finaldf_bowl['city'] = Match(x).town_name
        Finaldf_bowl['date'] = Match(x).date
        df=pd.concat([df,Finaldf_bowl])
    return(df)

# %%
getbowlingdatafame(testlist)
# Out:
#               name       Team Oppositionteam (O, overs) (M, maidens)  \
# 0       PJ Cummins  Australia          India         10            1
# 1  NM Coulter-Nile  Australia          India         10            0
# 2      JP Faulkner  Australia          India         10            1
# 3       MP Stoinis  Australia          India         10            0
# 4          A Zampa  Australia          India         10            0
# 0          B Kumar      India      Australia          4            0
# 1        JJ Bumrah      India      Australia          4            0
# 2        HH Pandya      India      Australia          4            0
# 3    Kuldeep Yadav      India      Australia          4            0
# 4        YS Chahal      India      Australia          5            0
# 0    Mohammad Amir   Pakistan          India        8.1            1
# 1       Imad Wasim   Pakistan          India        9.1            0
# 2        Hasan Ali   Pakistan          India         10            0
# 3       Wahab Riaz   Pakistan          India        8.4            0
# 4      Shadab Khan   Pakistan          India         10            0
# 5     Shoaib Malik   Pakistan          India          2            0
# 0          B Kumar      India       Pakistan          5            1
# 1         UT Yadav      India       Pakistan        7.4            1
# 2        JJ Bumrah      India       Pakistan          5            0
# 3        HH Pandya      India       Pakistan          8            0
# 4        RA Jadeja      India       Pakistan          8            0
#
#   (R, conceded) (W, wickets) (Econ, economyRate) (0s, dots)  \
# 0            44            0                4.40         33
# 1            44            3                4.40         38
# 2            67            1                6.70         31
# 3            54            2                5.40         27
# 4            66            1                6.60         26
# 0            25            1                6.25         10
# 1            20            1                5.00         13
# 2            28            2                7.00          9
# 3            33            2                8.25         12
# 4            30            3                6.00         16
# 0            32            0                3.91         30
# 1            66            0                7.20         22
# 2            70            1                7.00         30
# 3            87            0               10.03         13
# 4            52            1                5.20         21
# 5            10            0                5.00          5
# 0            23            1                4.60         17
# 1            30            3                3.91         30
# 2            23            0                4.60         17
# 3            43            2                5.37         23
# 4            43            2                5.37         28
#
#   (4s, foursConceded) (6s, sixesConceded) (WD, wides) (NB, noballs)  \
# 0                   3                   0           2             0
# 1                   5                   0           1             1
# 2                   8                   2           0             2
# 3                   3                   1           2             0
# 4                   3                   4           0             0
# 0                   2                   0           2             0
# 1                   2                   0           1             0
# 2                   2                   0           1             0
# 3                   1                   3           0             0
# 4                   1                   2           1             0
# 0                   4                   0           0             0
# 1                   4                   3           1             0
# 2                   7                   3           0             1
# 3                  11                   2           1             1
# 4                   0                   2           0             0
# 5                   1                   0           0             0
# 0                   1                   0           2             0
# 1                   3                   0           1             0
# 2                   3                   0           0             0
# 3                   4                   0           3             0
# 4                   4                   2           0             0
#
#          city        date
# 0     Chennai  2017-09-17
# 1     Chennai  2017-09-17
# 2     Chennai  2017-09-17
# 3     Chennai  2017-09-17
# 4     Chennai  2017-09-17
# 0     Chennai  2017-09-17
# 1     Chennai  2017-09-17
# 2     Chennai  2017-09-17
# 3     Chennai  2017-09-17
# 4     Chennai  2017-09-17
# 0  Birmingham  2017-06-04
# 1  Birmingham  2017-06-04
# 2  Birmingham  2017-06-04
# 3  Birmingham  2017-06-04
# 4  Birmingham  2017-06-04
# 5  Birmingham  2017-06-04
# 0  Birmingham  2017-06-04
# 1  Birmingham  2017-06-04
# 2  Birmingham  2017-06-04
# 3  Birmingham  2017-06-04
# 4  Birmingham  2017-06-04

# %%
a = json.loads(x.find_all('script')[12].get_text().replace("\n", " ").replace('window.__INITIAL_STATE__ =','').replace('&dagger;','wk').replace('&amp;','').replace('wkts;','wkts,').replace('wkt;','wkt,').strip().replace('};', "}};").split('};')[0])

# %%
df1bat = pd.DataFrame(a['gamePackage']['scorecard']['innings']['1']['batsmen'])
d1title = a['gamePackage']['scorecard']['innings']['1']['title']
df1bat['Team'] = d1title.split(' ')[0]

df2bat = pd.DataFrame(a['gamePackage']['scorecard']['innings']['2']['batsmen'])
d2title = a['gamePackage']['scorecard']['innings']['2']['title']
df2bat['Team'] = d2title.split(' ')[0]

df1bat['Oppositionteam'] = d2title.split(' ')[0]
df2bat['Oppositionteam'] = d1title.split(' ')[0]

# %%
def flatten(js):
    return pd.DataFrame(js).set_index(['text','name']).squeeze()

Finaldf_bat = pd.concat([df1bat.drop(['commentary','runningScore','runningOver', 'stats','hasVideoId','href','isNotOut','roles','shortText','trackingName'], axis=1),
#           df1.runningScore.apply(pd.Series),
           df1bat.stats.apply(flatten)], axis=1).append(pd.concat([df2bat.drop(['commentary','runningScore','runningOver', 'stats','hasVideoId','href','isNotOut','roles','shortText','trackingName'], axis=1),
#                                                               df2.runningScore.apply(pd.Series),
                                                               df2bat.stats.apply(flatten)], axis=1))

# %%
df1bowl = pd.DataFrame(a['gamePackage']['scorecard']['innings']['1']['bowlers'])
d1title = a['gamePackage']['scorecard']['innings']['1']['title']

df2bowl = pd.DataFrame(a['gamePackage']['scorecard']['innings']['2']['bowlers'])
d2title = a['gamePackage']['scorecard']['innings']['2']['title']

df1bowl['Team'] = d2title.split(' ')[0]
df2bowl['Team'] = d1title.split(' ')[0]

df1bowl['Oppositionteam'] = d1title.split(' ')[0]
df2bowl['Oppositionteam'] = d2title.split(' ')[0]

# %%
def flatten(js):
    return pd.DataFrame(js).set_index(['text','name']).squeeze()

Finaldf_bowl = pd.concat([df1bowl.drop(['stats','hasVideoId','href','roles','trackingName'], axis=1),
           df1bowl.stats.apply(flatten)], axis=1).append(pd.concat([df2bowl.drop(['stats','hasVideoId','href','roles','trackingName'], axis=1),
                                                               df2bowl.stats.apply(flatten)], axis=1))

# %%
Finaldf_bowl['city'] = Match('1022353').town_name
Finaldf_bowl['date'] = Match('1022353').date

# %%
m = Series('18808')
m.years
# Out:
# ['2019']
